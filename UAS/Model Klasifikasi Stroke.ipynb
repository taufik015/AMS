# %%
import pandas as pd

# %%
stroke = pd.read_csv('stroke.csv')

# %%
data = stroke.copy()

# %%
target = 'stroke'

# %%
encode = ['Residence_type', 'gender']

# %%
data
# Out:
#     stroke   age Residence_type  avg_glucose_level  gender
# 0      yes  67.0          Urban             228.69    Male
# 1      yes  61.0          Rural             202.21  Female
# 2      yes  80.0          Rural             105.92    Male
# 3      yes  49.0          Urban             171.23  Female
# 4      yes  79.0          Rural             174.12  Female
# ..     ...   ...            ...                ...     ...
# 701     No  38.0          Urban              88.97    Male
# 702     No  45.0          Rural              80.93  Female
# 703     No  66.0          Urban             102.07  Female
# 704     No  19.0          Rural              91.69  Female
# 705     No  49.0          Urban              63.71  Female
#
# [706 rows x 5 columns]

# %%
for col in encode:
    dummy = pd.get_dummies(data[col], prefix=col)
    data = pd.concat([data,dummy],axis=1) 
    del data[col]

# %%
data
# Out:
#     stroke   age  avg_glucose_level  Residence_type_Rural  \
# 0      yes  67.0             228.69                     0
# 1      yes  61.0             202.21                     1
# 2      yes  80.0             105.92                     1
# 3      yes  49.0             171.23                     0
# 4      yes  79.0             174.12                     1
# ..     ...   ...                ...                   ...
# 701     No  38.0              88.97                     0
# 702     No  45.0              80.93                     1
# 703     No  66.0             102.07                     0
# 704     No  19.0              91.69                     1
# 705     No  49.0              63.71                     0
#
#      Residence_type_Urban  gender_Female  gender_Male
# 0                       1              0            1
# 1                       0              1            0
# 2                       0              0            1
# ...

# %%
target_mapper = {'No':0, 'yes':1}

# %%
def target_encode(val):
    return target_mapper[val]

# %%
data['stroke'] = data['stroke'].apply(target_encode)

# %%
data
# Out:
#      stroke   age  avg_glucose_level  Residence_type_Rural  \
# 0         1  67.0             228.69                     0
# 1         1  61.0             202.21                     1
# 2         1  80.0             105.92                     1
# 3         1  49.0             171.23                     0
# 4         1  79.0             174.12                     1
# ..      ...   ...                ...                   ...
# 701       0  38.0              88.97                     0
# 702       0  45.0              80.93                     1
# 703       0  66.0             102.07                     0
# 704       0  19.0              91.69                     1
# 705       0  49.0              63.71                     0
#
#      Residence_type_Urban  gender_Female  gender_Male
# 0                       1              0            1
# 1                       0              1            0
# 2                       0              0            1
# ...

# %%
X = data.drop('stroke',axis=1)
Y = data['stroke']

# %%
X
# Out:
#       age  avg_glucose_level  Residence_type_Rural  Residence_type_Urban  \
# 0    67.0             228.69                     0                     1
# 1    61.0             202.21                     1                     0
# 2    80.0             105.92                     1                     0
# 3    49.0             171.23                     0                     1
# 4    79.0             174.12                     1                     0
# ..    ...                ...                   ...                   ...
# 701  38.0              88.97                     0                     1
# 702  45.0              80.93                     1                     0
# 703  66.0             102.07                     0                     1
# 704  19.0              91.69                     1                     0
# 705  49.0              63.71                     0                     1
#
#      gender_Female  gender_Male
# 0                0            1
# ...

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 701    0
# 702    0
# 703    0
# 704    0
# 705    0
# Name: stroke, Length: 706, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X,Y)
# Out:
# GaussianNB()

# %%
import pickle
pickle.dump(model, open('modelNBC_stroke.pkl','wb'))
